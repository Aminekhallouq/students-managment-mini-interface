# %% [markdown]
# # libraries

# %%
from tkinter import *
import tkinter.ttk as ttk
import sqlite3

# %% [markdown]
# # code

# %%
class user:
    def __init__(self,root):                                                    
        self.root=root
        self.database_creation()
        self.user_creation()
    def user_creation(self):
        self.f=Frame(self.root)
        self.f.config(width=400,height=500,background='black')
        self.f.place(x=0,y=0)
        Label(self.f,text='you are ?',background='black',fg='magenta',width=20).place(x=120,y=100)
        Button(self.f,text='Admin',width=25,height=3,command=self.admin_creation,bg='blue',fg='black',activebackground='green',borderwidth='2').place(x=0,y=170)
        Button(self.f,text='student',width=25,height=3,command=self.eleve_creation,bg='blue',fg='black',activebackground='green',borderwidth='2').place(x=220,y=170)
    def database_creation(self):
        self.db=sqlite3.connect('classes.db')
        self.cu=self.db.cursor()
        try:
            self.cu.execute('''create table etudiant(
            id-student integer ptimary key unique,
            id-major references filiere(idfiliere),
            last_name  text,
            first_name text,
            age integer )''')
        except sqlite3.OperationalError:
            pass
        try:
            self.cu.execute('''create table filiere(
            id-major integer primary key unique,
            major text)''')
        except sqlite3.OperationalError:
            pass
    def admin_creation(self):
        self.f.place_forget()
        self.f2=Frame(self.root)
        self.f2.config(width=400,height=500,background='black')
        self.f2.place(x=0,y=0)
        Label(self.f2,text=' Admin space',bg='black',fg='cyan').place(x=140,y=20)
        Button(self.f2,text='show listes',command=self.afficher,width=20,height=1,bg='black',fg='cyan').place(x=115,y=350)
        Button(self.f2,text='add student',command=self.ajouter_eleve,width=20,height=1,bg='black',fg='cyan',activebackground='green').place(x=10,y=110)
        Button(self.f2,text='modifie student ',command=self.modifier_eleve,width=20,height=1,bg='black',fg='cyan',activebackground='green').place(x=10,y=150)
        Button(self.f2,text='delete student',command=self.supprimer_eleve,width=20,height=1,bg='black',fg='cyan',activebackground='green').place(x=220,y=110)
        Button(self.f2,text='add major',command=self.ajouter_filiere,width=20,height=1,bg='black',fg='cyan',activebackground='green').place(x=10,y=190)
        Button(self.f2,text='modifie major',command=self.modifier_filiere,width=20,height=1,bg='black',fg='cyan',activebackground='green').place(x=220,y=150)
        Button(self.f2,text='delete major',command=self.supprimer_filiere,width=20,height=1,bg='black',fg='cyan',activebackground='green').place(x=220,y=190)
        ret=retour(self.root,self.f2,self)
        Button(self.f2,command=ret.retour1,text='🡰',bg='black',fg='red',borderwidth='2').place(x=0,y=0)
    def eleve_creation(self):
        self.f.place_forget()
        self.f3=Frame(self.root)
        self.f3.config(width=500,height=500,background='black')
        self.f3.place(x=0,y=0)
        Label(self.f3,text='student space',bg='black',fg='cyan').place(x=140,y=20)
        Button(self.f3,text='apply',command=self.s_inscrire,width=20,height=1,bg='black',fg='magenta',activebackground='green').place(x=115,y=110)
        Button(self.f3,text='modifie informations',command=self.modifier,width=20,height=1,bg='black',fg='magenta',activebackground='green').place(x=115,y=150)
        Button(self.f3,text='delete my informations',command=self.supprimer,width=20,height=1,bg='black',fg='magenta',activebackground='green').place(x=115,y=190)
        ret=retour(self.root,self.f3,self)
        Button(self.f3,command=ret.retour1,text='🡰',bg='black',fg='red',borderwidth='2').place(x=0,y=0)
    def ajouter_eleve(self):
        self.f2.place_forget()
        self.f4=Frame(self.root)
        self.f4.config(width=400,height=500,background='black')
        self.f4.place(x=0,y=0)
        self.l=Label(self.f4,text="Add student ",bg='black',fg='green',borderwidth='0')
        self.l.place(x=130,y=20)
        l1=Label(self.f4,text='id-student',bg='black',fg='white').place(x=60,y=80)
        self.e1=Entry(self.f4,bg='gray',fg='white')
        self.e1.place(x=125,y=80)
        l2=Label(self.f4,text='id-major',bg='black',fg='white').place(x=60,y=120)
        self.e2=Entry(self.f4,bg='gray',fg='white')
        self.e2.place(x=125,y=120)
        l3=Label(self.f4,text='last_name',bg='black',fg='white').place(x=60,y=160)
        self.e3=Entry(self.f4,bg='gray',fg='white')
        self.e3.place(x=125,y=160)
        l4=Label(self.f4,text='first_name',bg='black',fg='white').place(x=60,y=200)
        self.e4=Entry(self.root,bg='gray',fg='white')
        self.e4.place(x=125,y=200)
        l5=Label(self.f4,text='age',bg='black',fg='white').place(x=60,y=240)
        self.e5=Entry(self.f4,bg='gray',fg='white')
        self.e5.place(x=125,y=240)
        Button(self.f4,command=self.real_ajout,text='add',bg='black',fg='green').place(x=230,y=280)
        ret=retour(self.root,self.f4,self)
        Button(self.f4,command=ret.retour2,text='🡰',bg='black',fg='red',borderwidth='2').place(x=0,y=0)
    def real_ajout(self):
        if not self.e1.get().isdigit():
            self.l.config(text='id-student : integer only !',fg='red')
        elif not self.e2.get().isdigit():
            self.l.config(text='id-major : integer only!',fg='red')
        elif not self.e3.get().isalpha() or not self.e4.get().isalpha():
            self.l.config(text='first_name and last_name: only letters!',fg='red')
        elif not self.e5.get().isdigit():
            self.l.config(text='impossible age!',fg='red')
        else :
            try:
                self.cu.execute('''insert into etudiant values(?,?,?,?,?);''',(int(self.e1.get()),int(self.e2.get()),self.e3.get(),self.e4.get(),int(self.e5.get())))
                self.db.commit()
                self.f4.place_forget()
                self.admin_creation()
            except sqlite3.IntegrityError:
                self.l.config(text='id allready exists',fg='red')
    def modifier_eleve(self):
        self.f2.place_forget()
        self.f5=Frame(self.root)
        self.f5.config(width=400,height=500,background='black')
        self.f5.place(x=0,y=0)
        self.la=Label(self.f5,text="modification",bg='black',fg='green',borderwidth='0')
        self.la.place(x=130,y=20)
        l1=Label(self.f5,text='id-student',bg='black',fg='white').place(x=60,y=80)
        self.a1=Entry(self.f5,bg='gray',fg='white')
        self.a1.place(x=125,y=80)
        l2=Label(self.f5,text='id-major',bg='black',fg='white').place(x=60,y=120)
        self.a2=Entry(self.f5,bg='gray',fg='white')
        self.a2.place(x=125,y=120)
        l3=Label(self.f5,text='last_name',bg='black',fg='white').place(x=60,y=160)
        self.a3=Entry(self.f5,bg='gray',fg='white')
        self.a3.place(x=125,y=160)
        l4=Label(self.f5,text='first_name',bg='black',fg='white').place(x=60,y=200)
        self.a4=Entry(self.f5,bg='gray',fg='white')
        self.a4.place(x=125,y=200)
        l5=Label(self.f5,text='age',bg='black',fg='white').place(x=60,y=240)
        self.a5=Entry(self.f5,bg='gray',fg='white')
        self.a5.place(x=125,y=240)
        Button(self.f5,command=self.real_modif,text='modifier',bg='black',fg='green').place(x=230,y=280)
        ret=retour(self.root,self.f5,self)
        Button(self.f5,command=ret.retour2,text='🡰',bg='black',fg='red',borderwidth='2').place(x=0,y=0)
    def real_modif(self):
        self.cu.execute('''select * from etudiant;''')
        eleves=self.cu.fetchall()
        el=[eleve[0] for eleve in eleves]
        if not self.a1.get().isdigit() or int(self.a1.get()) not in el:
            self.la.config(text='student doesnt exist!',fg='red')
        elif not self.a2.get().isdigit() :
            self.la.config(text='id-major : only integers!',fg='red')
        elif not self.a3.get().isalpha() or not self.a4.get().isalpha():
            self.la.config(text='first_name and last_name: only letters',fg='red')
        elif not self.a5.get().isdigit():
            self.la.config(text='age impossible !',fg='red')
        else :
            self.cu.execute('''update etudiant set id-major=?,last_name=?,first_name=?,age=? where id-student=?''',(int(self.a2.get()),self.a3.get(),self.a4.get(),int(self.a5.get()),int(self.a1.get())))
            self.db.commit()
            self.f5.place_forget()
            self.admin_creation()
    def supprimer_eleve(self):
        self.f2.place_forget()
        self.f6=Frame(self.root)
        self.f6.config(width=400,height=500,background='black')
        self.f6.place(x=0,y=0)
        self.ls=Label(self.f6,text="delete",bg='black',fg='red',borderwidth='0')
        self.ls.place(x=175,y=35)
        l1=Label(self.f6,text='id-student',bg='black',fg='white').place(x=60,y=75)
        self.s=Entry(self.f6,bg='white',fg='black')
        self.s.place(x=140,y=75)
        Button(self.f6,command=self.real_suppr,text='delete',bg='black',fg='red').place(x=225,y=110)
        ret=retour(self.root,self.f6,self)
        Button(self.f6,command=ret.retour2,text='🡰',bg='black',fg='red',borderwidth='2').place(x=0,y=0)
    def real_suppr(self):
        self.cu.execute('''select * from etudiant;''')
        eleves=self.cu.fetchall()
        el=[eleve[0] for eleve in eleves]
        if not self.s.get().isdigit() or int(self.s.get()) not in el:
            self.ls.config(text='this id doesnt exist')
        else:
            self.cu.execute('''delete from etudiant where id-student=%d'''%int(self.s.get()))
            self.db.commit()
            self.f6.place_forget()
            self.admin_creation()
    def ajouter_filiere(self):
        self.f2.place_forget()
        self.f7=Frame(self.root)
        self.f7.config(width=400,height=500,background='black')
        self.f7.place(x=0,y=0)
        self.lf=Label(self.f7,text="add major",bg='black',fg='green',borderwidth='0')
        self.lf.place(x=135,y=20)
        l=Label(self.f7,text='id-major',bg='black',fg='white').place(x=60,y=80)
        self.t1=Entry(self.f7,bg='gray',fg='white')
        self.t1.place(x=125,y=80)
        l=Label(self.f7,text='major',bg='black',fg='white').place(x=60,y=120)
        self.t2=Entry(self.f7,bg='gray',fg='white')
        self.t2.place(x=125,y=120)
        Button(self.f7,command=self.real_ajout_fil,text='add',bg='black',fg='green').place(x=230,y=160)
        ret=retour(self.root,self.f7,self)
        Button(self.f7,command=ret.retour2,text='🡰',bg='black',fg='red',borderwidth='2').place(x=0,y=0)
    def real_ajout_fil(self):
        self.cu.execute('''select * from filiere;''')
        filieres=self.cu.fetchall()
        fi=[filiere[0] for filiere in filieres]
        fi2=[filiere[1] for filiere in filieres]
        if not self.t1.get().isdigit():
            self.lf.config(text='id-major : only integers',fg='red')
        elif int(self.t1.get()) in fi :
            self.lf.config(text='this id allready exists',fg='red')
        elif self.t2.get() in fi2:
            self.lf.config(text='this major allready exists',fg='red')
        elif self.t2.get().isdigit():
            self.lf.config(text='entrer a vailable number',fg='red')
        else:
            self.cu.execute('''insert into filiere values(?,?);''',(int(self.t1.get()),self.t2.get()))
            self.db.commit()
            self.f7.place_forget()
            self.admin_creation()
    def modifier_filiere(self):
        self.f2.place_forget()
        self.f8=Frame(self.root)
        self.f8.config(width=400,height=500,background='black')
        self.f8.place(x=0,y=0)
        self.lm=Label(self.f8,text="modifie major",bg='black',fg='green',borderwidth='0')
        self.lm.place(x=135,y=20)
        l=Label(self.f8,text='id-major',bg='black',fg='white').place(x=60,y=80)
        self.k1=Entry(self.f8,bg='gray',fg='white')
        self.k1.place(x=125,y=80)
        l=Label(self.f8,text='major',bg='black',fg='white').place(x=60,y=120)
        self.k2=Entry(self.f8,bg='gray',fg='white')
        self.k2.place(x=125,y=120)
        Button(self.f8,command=self.real_modif_fil,text='modifie',bg='black',fg='green').place(x=230,y=150)
        ret=retour(self.root,self.f8,self)
        Button(self.f8,command=ret.retour2,text='🡰',bg='black',fg='red',borderwidth='2').place(x=0,y=0)
    def real_modif_fil(self):
        self.cu.execute('''select * from filiere;''')
        filieres=self.cu.fetchall()
        fi=[filiere[0] for filiere in filieres]
        if not self.k1.get().isdigit() or int(self.k1.get()) not in fi:
            self.lm.config(text="enter a vailable student",fg="red")
        elif self.k2.get().isdigit():
            self.lm.config(text=' name doesnt exist',fg="red")
        else:
            self.cu.execute('''update filiere set major=? where id-major=?''',(self.k2.get(),int(self.k1.get())))
            self.db.commit()
            self.f8.place_forget()
            self.admin_creation()
    def supprimer_filiere(self):
        self.f2.forget()
        self.f9=Frame(self.root)
        self.f9.config(width=400,height=500,background='black')
        self.f9.place(x=0,y=0)
        self.fs=Label(self.f9,text="delete major ",bg='black',fg='red',borderwidth='0')
        self.fs.place(x=130,y=20)
        l=Label(self.f9,text='id-major',bg='black',fg='white').place(x=60,y=80)
        self.s1=Entry(self.f9,bg='white',fg='black')
        self.s1.place(x=125,y=80)
        Button(self.f9,command=self.real_suppr_fil,text='delete',bg='black',fg='red').place(x=210,y=110)
        ret=retour(self.root,self.f9,self)
        Button(self.f9,command=ret.retour2,text='🡰',bg='black',fg='red',borderwidth='2').place(x=0,y=0)
    def real_suppr_fil(self):
        self.cu.execute('''select * from filiere;''')
        filieres=self.cu.fetchall()
        fi=[filiere[0] for filiere in filieres]
        try:
            if not self.s1.get().isdigit() or int(self.s1.get()) not in fi:
                self.fs.config(text='enter a vailabel id',fg='red')
            else:
                self.cu.execute('''delete from filiere where idfiliere=%d'''%int(self.s1.get()))
                self.db.commit()
                self.f9.place_forget()
                self.admin_creation()
        except:
            self.fs.config(text='enter vailable id',fg='red')
    def s_inscrire(self):
        self.f3.place_forget()
        self.f10=Frame(self.root)
        self.f10.config(width=400,height=500,background='black')
        self.f10.place(x=0,y=0)
        self.es=Label(self.f10,text="inscription",bg='black',fg='green',borderwidth='0')
        self.es.place(x=170,y=20)
        l1=Label(self.f10,text='id-student',bg='black',fg='white').place(x=60,y=80)
        self.el1=Entry(self.f10,bg='gray',fg='white')
        self.el1.place(x=125,y=80)
        l2=Label(self.f10,text='major',bg='black',fg='white').place(x=60,y=120)
        self.el2=Entry(self.f10,bg='gray',fg='white')
        self.el2.place(x=125,y=120)
        l3=Label(self.f10,text='last_name',bg='black',fg='white').place(x=60,y=160)
        self.el3=Entry(self.f10,bg='gray',fg='white')
        self.el3.place(x=125,y=160)
        l4=Label(self.f10,text='first-name',bg='black',fg='white').place(x=60,y=200)
        self.el4=Entry(self.root,bg='gray',fg='white')
        self.el4.place(x=125,y=200)
        l5=Label(self.f10,text='age',bg='black',fg='white').place(x=60,y=240)
        self.el5=Entry(self.f10,bg='gray',fg='white')
        self.el5.place(x=125,y=240)
        Button(self.f10,command=self.real_inscr,text='add',bg='black',fg='green').place(x=230,y=270)
        ret=retour(self.root,self.f10,self)
        Button(self.f10,text='🡰',command=ret.retour3,bg='black',fg='red',borderwidth='2').place(x=0,y=0)
    def real_inscr(self):
        self.cu.execute('''select * from etudiant;''')
        eleves=self.cu.fetchall()
        el=[eleve[0] for eleve in eleves]
        self.cu.execute('''select * from filiere;''')
        filieres=self.cu.fetchall()
        fi=[filiere[1] for filiere in filieres]
        if not self.el1.get().isdigit() or int(self.el1.get()) in el:
            self.es.config(text='enter vialable id',fg='red')
        elif self.el2.get() not in fi:
            self.es.config(text='this major doesnt exist',fg='red')
        elif not self.el3.get().isalpha() or not self.el4.get().isalpha():
            self.es.config(text='name :only letters',fg='red')
        elif not self.el5.get().isdigit():
            self.es.config(text='age impossible',fg='red')
        else :
            l=[filiere[0] for filiere in filieres if filiere[1]==self.el2.get()]
            v=l[0]
            self.cu.execute('''insert into etudiant values(?,?,?,?,?);''',(int(self.el1.get()),v,self.el3.get(),self.el4.get(),int(self.el5.get())))
            self.db.commit()
            self.f10.place_forget()
            self.eleve_creation()
        
    def modifier(self):
        self.f3.forget()
        self.f11=Frame(self.root)
        self.f11.config(width=400,height=500,background='black')
        self.f11.place(x=0,y=0)
        self.lme=Label(self.f11,text="modification",bg='black',fg='green',borderwidth='0')
        self.lme.place(x=160,y=20)
        l1=Label(self.f11,text='id-student',bg='black',fg='white').place(x=60,y=80)
        self.mo1=Entry(self.f11,bg='gray',fg='white')
        self.mo1.place(x=125,y=80)
        l2=Label(self.f11,text='last_name',bg='black',fg='white').place(x=60,y=120)
        self.mo2=Entry(self.f11,bg='gray',fg='white')
        self.mo2.place(x=125,y=120)
        l3=Label(self.f11,text='first_name',bg='black',fg='white').place(x=60,y=160)
        self.mo3=Entry(self.f11,bg='gray',fg='white')
        self.mo3.place(x=125,y=160)
        l4=Label(self.f11,text='major',bg='black',fg='white').place(x=60,y=200)
        self.mo4=Entry(self.f11,bg='gray',fg='white')
        self.mo4.place(x=125,y=200)
        l5=Label(self.f11,text='age',bg='black',fg='white').place(x=60,y=240)
        self.mo5=Entry(self.f11,bg='gray',fg='white')
        self.mo5.place(x=125,y=240)
        Button(self.f11,command=self.real_modif_elev,text='modifie',bg='black',fg='green').place(x=230,y=270)
        ret=retour(self.root,self.f11,self)
        Button(self.f11,text='🡰',command=ret.retour3,bg='black',fg='red',borderwidth='2').place(x=0,y=0)
    def real_modif_elev(self):
        self.cu.execute('''select * from etudiant;''')
        eleves=self.cu.fetchall()
        el=[eleve[0] for eleve in eleves]
        self.cu.execute('''select * from filiere;''')
        filieres=self.cu.fetchall()
        fi=[filiere[1] for filiere in filieres]
        if not self.mo1.get().isdigit() or int(self.mo1.get()) not in el:
            self.lme.config(text='this id doesnt exist',fg='red')
        elif not self.mo2.get().isalpha() or not self.mo3.get().isalpha():
            self.lme.config(text='first_name and last_name: only letters',fg='red')
        elif not self.mo5.get().isdigit():
            self.lme.config(text='age impossible',fg='red')
        elif self.mo4.get() not in fi:
            self.lme.config(text='this major doesnt exist',fg='red')
        elif self.mo4.get().isdigit():
            self.lme.config(text='insert vailable major',fg='red')
        else :
            l=[filiere[0] for filiere in filieres if filiere[1]==self.mo4.get()]
            v=l[0]
            self.cu.execute('''update etudiant set id-major=?,last_name=?,first_name=?,age=? where id-student=?''',(v,self.mo3.get(),self.mo4.get(),int(self.mo5.get()),int(self.mo1.get())))
            self.db.commit()
            self.f11.place_forget()
            self.eleve_creation()
    def supprimer(self):
        self.f3.place_forget()
        self.f12=Frame(self.root)
        self.f12.config(width=400,height=500,background='black')
        self.f12.place(x=0,y=0)
        self.lsem=Label(self.f12,text="delete",bg='black',fg='red',borderwidth='0')
        self.lsem.place(x=160,y=20)
        l1=Label(self.f12,text='id-student',bg='black',fg='white').place(x=60,y=80)
        self.se=Entry(self.f12,bg='white',fg='black')
        self.se.place(x=125,y=80)
        Button(self.f12,command=self.real_suppr_elev,text='delete',bg='black',fg='red').place(x=215,y=110)
        ret=retour(self.root,self.f12,self)
        Button(self.f12,command=ret.retour3,text='🡰',bg='black',fg='red',borderwidth='2').place(x=0,y=0)
    def real_suppr_elev(self):
        self.cu.execute('''select * from etudiant;''')
        eleves=self.cu.fetchall()
        el=[eleve[0] for eleve in eleves]
        if not self.se.get().isdigit() or int(self.se.get()) not in el :
            self.lsem.config(text='this id doesnt exist')
        else:
            self.cu.execute('''delete from etudiant where id-student=%d;'''%int(self.se.get()))
            self.db.commit()
            self.f12.place_forget()
            self.eleve_creation()
    def afficher(self):
        self.f2.place_forget()
        self.fa=Frame(self.root)
        self.fa.config(width=500,height=400,bg='black')
        self.fa.place(x=0,y=0)
        self.laff=Label(self.fa,text="show majors list:",bg='black',fg='cyan')
        self.laff.place(x=110,y=100)
        self.cu.execute('''select * from filiere;''')
        filieres=self.cu.fetchall()
        l=[filiere[1] for filiere in filieres]
        self.c=ttk.Combobox(self.fa, values=l)
        self.c.place(x=60,y=190)
        Button(self.fa,text='show',command=self.real_affich,bg='black',fg='cyan').place(x=250,y=190)
        ret=retour(self.root,self.fa,self)
        Button(self.fa,command=ret.retour2,text='🡰',bg='black',fg='red',borderwidth='2').place(x=0,y=0)
    def real_affich(self):
        try:
            r=Tk()
            r.geometry('600x900')
            r.config(bg='white')
            self.cu.execute('''select * from filiere;''')
            filieres=self.cu.fetchall()
            l=[filiere[0] for filiere in filieres if filiere[1]==self.c.get()]
            v=l[0]
            self.cu.execute('''select * from etudiant where id-major=%d;'''%v)
            eleves=self.cu.fetchall()
            self.db.commit()
            s="liste de la filiere : {}".format(self.c.get())
            Label(r,text=s,bg='white').place(x=200,y=2)
            s1="id-student              last_name             first_name              major              age"
            Label(r,text=s1,bg='white').place(x=0,y=50)
            for i,e in enumerate(eleves):
                s="{}                        {}                      {}                       {}                   {}".format(e[0],e[2],e[3],self.c.get(),e[4])
                Label(r,text=s,bg='white').place(x=0,y=(100+i*50))
            r.mainloop()
        except:
            self.laff.config(text='chose a list please !')

# %%
class retour:
        def __init__(self,root,fr,instance):
            self.frame=fr
            self.roor=root
            self.user=instance
        def retour1(self):
            self.frame.place_forget()
            self.user.user_creation()
        def retour2(self):
            self.frame.place_forget()
            self.user.admin_creation()
        def retour3(self):
            self.frame.place_forget()
            self.user.eleve_creation()

# %%
r=Tk()
r.config(background='black')
r.geometry('400x500')
u=user(r)
u.db.commit()
r.mainloop()
u.db.close()
